# %%
import csv
import pandas as pd

# %%
df = pd.read_csv('c:/users/rusty/documents/moby/ipave/data/new_data.csv',
                 names = ['IP_Address', 'Subnet_mask', 'In_use?', 'unix_timestamp'])

# %%
df
# Out:
#      IP_Address  Subnet_mask  In_use?  unix_timestamp
# 0    10.128.0.0           22        0      1525670182
# 1    10.128.4.0           22        0      1525670192
# 2    10.128.8.0           22        0      1525670202
# 3   10.128.12.0           22        0      1525670212
# 4   10.128.16.0           22        0      1525670222
# 5  10.128.128.0           24        0      1525670222
# 6  10.128.129.0           24        0      1525670222
# 7  10.128.130.0           24        0      1525670222
# 8  10.128.131.0           24        0      1525670222
# 9  10.128.132.0           22        0      1525670222

# %%
df['IP_Address'].count()
# Out:
# 10

# %%
dic = {22:4, 24:1}

# %%
df['mask_conversion'] = df['Subnet_mask'].map(dic)

# %%
df
# Out:
#      IP_Address  Subnet_mask  In_use?  unix_timestamp  mask_conversion
# 0    10.128.0.0           22        0      1525670182                4
# 1    10.128.4.0           22        0      1525670192                4
# 2    10.128.8.0           22        0      1525670202                4
# 3   10.128.12.0           22        0      1525670212                4
# 4   10.128.16.0           22        0      1525670222                4
# 5  10.128.128.0           24        0      1525670222                1
# 6  10.128.129.0           24        0      1525670222                1
# 7  10.128.130.0           24        0      1525670222                1
# 8  10.128.131.0           24        0      1525670222                1
# 9  10.128.132.0           22        0      1525670222                4

# %%
df['mask_conversion'].sum()
# Out:
# 28

# %%
df2 = df[['unix_timestamp', 'IP_Address', 'Subnet_mask', 'In_use?']]
df2
# Out:
#    unix_timestamp    IP_Address  Subnet_mask  In_use?
# 0      1525670182    10.128.0.0           22        0
# 1      1525670192    10.128.4.0           22        0
# 2      1525670202    10.128.8.0           22        0
# 3      1525670212   10.128.12.0           22        0
# 4      1525670222   10.128.16.0           22        0
# 5      1525670222  10.128.128.0           24        0
# 6      1525670222  10.128.129.0           24        0
# 7      1525670222  10.128.130.0           24        0
# 8      1525670222  10.128.131.0           24        0
# 9      1525670222  10.128.132.0           22        0

# %%
df3 = df2.set_index(['unix_timestamp'])
df3
# Out:
#                   IP_Address  Subnet_mask  In_use?
# unix_timestamp
# 1525670182        10.128.0.0           22        0
# 1525670192        10.128.4.0           22        0
# 1525670202        10.128.8.0           22        0
# 1525670212       10.128.12.0           22        0
# 1525670222       10.128.16.0           22        0
# 1525670222      10.128.128.0           24        0
# 1525670222      10.128.129.0           24        0
# 1525670222      10.128.130.0           24        0
# 1525670222      10.128.131.0           24        0
# 1525670222      10.128.132.0           22        0

# %%
#df3.set_value('1525670192', 'In_use?', 1)
df3.at['1525670192', 'In_use?'] =1
df3
# Out:
#                   IP_Address  Subnet_mask  In_use?
# unix_timestamp
# 1525670182        10.128.0.0           22        0
# 1525670192        10.128.4.0           22        1
# 1525670202        10.128.8.0           22        0
# 1525670212       10.128.12.0           22        0
# 1525670222       10.128.16.0           22        0
# 1525670222      10.128.128.0           24        0
# 1525670222      10.128.129.0           24        0
# 1525670222      10.128.130.0           24        0
# 1525670222      10.128.131.0           24        0
# 1525670222      10.128.132.0           22        0

# %%
#df3 = df3.groupby(['unix_timestamp', 'IP_Address', 'In_use?']).agg(['count'])

# %%
df4 = df3.reset_index()
df4.set_index(['unix_timestamp', 'IP_Address', 'In_use?']).unstack(level=-1)
# Out:
#                             Subnet_mask
# In_use?                               0     1
# unix_timestamp IP_Address
# 1525670182     10.128.0.0          22.0   NaN
# 1525670192     10.128.4.0           NaN  22.0
# 1525670202     10.128.8.0          22.0   NaN
# 1525670212     10.128.12.0         22.0   NaN
# 1525670222     10.128.128.0        24.0   NaN
#                10.128.129.0        24.0   NaN
#                10.128.130.0        24.0   NaN
#                10.128.131.0        24.0   NaN
#                10.128.132.0        22.0   NaN
#                10.128.16.0         22.0   NaN
